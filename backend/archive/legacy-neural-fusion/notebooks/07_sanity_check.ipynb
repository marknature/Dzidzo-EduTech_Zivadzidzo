# %% [markdown]
# # Neural/fusion sanity check
# Validates artifact schema, selected model names, fusion-weight sums, and the shared-trunk input shape.

# %%
from smoke_neural_fusion import main as smoke_neural_fusion
smoke_neural_fusion()
# Out:
# {
#   "status": "passed",
#   "artifact": "industry4_neural_fusion_v1",
#   "selected_classifier": "nearest_centroid",
#   "selected_regressor": "linear_regression",
#   "fusion_f1": 0.9951,
#   "fusion_mae": 0.8621
# }
