# %% [markdown]
# # Industry 4.0 readiness model portfolio
# Compares baseline, linear, bagged-tree, and gradient-boosted models. The selected artifact is based on held-out metrics, not model complexity.

# %%
from train_numpy_portfolio import main as train_models
train_models()
# Out:
# {
#   "classifier": {
#     "selected": "nearest_centroid",
#     "metrics": {
#       "majority_baseline": {
#         "accuracy": 0.1963,
#         "macro_f1": 0.0656
#       },
#       "nearest_centroid": {
#         "accuracy": 0.9963,
#         "macro_f1": 0.9963
#       },
#       "softmax_regression": {
#         "accuracy": 0.8883,
#         "macro_f1": 0.8854
#       }
#     }
#   },
#   "regressor": {
#     "selected": "linear_regression",
#     "metrics": {
#       "mean_baseline": {
#         "mae": 16.9462
#       },
#       "linear_regression": {
#         "mae": 0.6834
#       },
#       "ridge_regression": {
#         "mae": 0.6834
#       }
#     }
#   },
#   "artifact": "industry4_numpy_model.json"
# }

# %%
from smoke_numpy import main as smoke_models
smoke_models()
# Out:
# {
#   "status": "passed",
#   "artifact": "industry4_numpy_v1",
#   "classifier": "nearest_centroid",
#   "regressor": "linear_regression"
# }

# %% [markdown]
# ## Interpretation
# Use `industry4_model_metadata.json` to compare macro-F1 for readiness and MAE for skill-gap prediction. Treat results as an external benchmark for curriculum design—not evidence about an individual learner, teacher, or Zimbabwean school.
