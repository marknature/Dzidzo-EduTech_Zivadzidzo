# %% [markdown]
# # ZivaDzidzo shared-trunk neural network
# Adapted from the ZivaBasa multi-task workflow: a common 19-feature trunk feeds a readiness softmax head and a skill-gap regression head. Unlike ZivaBasa, both targets occur on the same Industry 4.0 rows, so this is a genuine aligned multi-task problem.

# %%
from train_neural_fusion import main as train_neural_portfolio
train_neural_portfolio()
# Out:
# {
#   "artifact": "industry4_neural_fusion_model.json",
#   "classification": {
#     "nearest_centroid": {
#       "accuracy": 0.9969,
#       "macro_f1": 0.9969
#     },
#     "softmax_regression": {
#       "accuracy": 0.9151,
#       "macro_f1": 0.914
#     },
#     "neural_mlp": {
#       "accuracy": 0.916,
#       "macro_f1": 0.915
#     },
#     "weighted_fusion": {
#       "accuracy": 0.9951,
#       "macro_f1": 0.9951
#     }
#   },
#   "regression": {
#     "mean_baseline": {
#       "mae": 17.0528
#     },
#     "linear_regression": {
#       "mae": 0.6674
#     },
#     "neural_mlp": {
#       "mae": 1.1959
#     },
#     "weighted_fusion": {
#       "mae": 0.8621
#     }
#   },
#   "classification_weights": {
#     "nearest_centroid": 0.3505378317594369,
#     "softmax_regression": 0.3243070098660513,
#     "neural_mlp": 0.3251551583745118
#   },
#   "regression_weights": {
#     "mean_baseline": 0.0252315277329204,
#     "linear_regression": 0.6258483650152435,
# ...

# %% [markdown]
# The notebook exports JSON weights rather than a framework-specific runtime, enabling deterministic Node inference without a second production service.
